# %%
def afficher_N(N):  
    def decorateur(func):
        def wrapper(*args, **kwargs):
            print(f"début N = {N}")
            func(*args, **kwargs)
            print("fin")
        return wrapper
    return decorateur

@afficher_N(5)
def amis(n):
    print(f"j'ai {n} amis !")



amis(10)
# Out:
# début N = 5
# j'ai 10 amis !
# fin

# %%
import bcrypt

password = b"mysecretpassword" # Password must be in bytes
salt = bcrypt.gensalt()
hashed_password = bcrypt.hashpw(password, salt)

print(hashed_password)
# Out:
# b'$2b$12$QkQKXimpfQ.zVGYlww/QQetXTODufoLr12Q0Av9NIFAKt40UfuRUW'

# %%
from passlib.context import CryptContext

pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

def hash_password(password: str) -> str:
    # S'assurer que c’est bien une string simple
    print(password)
    password = str(password)
    
    return pwd_context.hash(password)

hash_password("string")
# Out:
# (trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/Users/martintarot/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# string
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 12
#       8     password = str(password)
#      10     return pwd_context.hash(password)
# ---> 12 hash_password("string")
#
# Cell In[4], line 10, in hash_password(password)
#       7 print(password)
#       8 password = str(password)
# ---> 10 return pwd_context.hash(password)
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/context.py:2258, in CryptContext.hash(self, secret, scheme, category, **kwds)
#    2256 if strip_unused:
#    2257     strip_unused(kwds, record)
# -> 2258 return record.hash(secret, **kwds)
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:779, in GenericHandler.hash(cls, secret, **kwds)
#     777 validate_secret(secret)
#     778 self = cls(use_defaults=True, **kwds)
# --> 779 self.checksum = self._calc_checksum(secret)
#     780 return self.to_string()
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/handlers/bcrypt.py:591, in _NoBackend._calc_checksum(self, secret)
#     590 def _calc_checksum(self, secret):
# --> 591     self._stub_requires_backend()
#     592     # NOTE: have to use super() here so that we don't recursively
#     593     #       call subclass's wrapped _calc_checksum, e.g. bcrypt_sha256._calc_checksum
#     594     return super(bcrypt, self)._calc_checksum(secret)
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:2254, in BackendMixin._stub_requires_backend(cls)
#    2251 if cls.__backend:
#    2252     raise AssertionError("%s: _finalize_backend(%r) failed to replace lazy loader" %
#    2253                          (cls.name, cls.__backend))
# -> 2254 cls.set_backend()
#    2255 if not cls.__backend:
#    2256     raise AssertionError("%s: set_backend() failed to load a default backend" %
#    2257                          (cls.name))
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:2156, in BackendMixin.set_backend(cls, name, dryrun)
#    2154 owner = cls._get_backend_owner()
#    2155 if owner is not cls:
# -> 2156     return owner.set_backend(name, dryrun=dryrun)
#    2158 # pick first available backend
#    2159 if name == "any" or name == "default":
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:2163, in BackendMixin.set_backend(cls, name, dryrun)
#    2161 for name in cls.backends:
#    2162     try:
# -> 2163         return cls.set_backend(name, dryrun=dryrun)
#    2164     except exc.MissingBackendError:
#    2165         continue
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:2188, in BackendMixin.set_backend(cls, name, dryrun)
#    2186     cls._pending_backend = name
#    2187     cls._pending_dry_run = dryrun
# -> 2188     cls._set_backend(name, dryrun)
#    2189 finally:
#    2190     cls._pending_backend, cls._pending_dry_run = orig
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:2311, in SubclassBackendMixin._set_backend(cls, name, dryrun)
#    2308 @classmethod
#    2309 def _set_backend(cls, name, dryrun):
#    2310     # invoke backend loader (will throw error if fails)
# -> 2311     super(SubclassBackendMixin, cls)._set_backend(name, dryrun)
#    2313     # sanity check call args (should trust .set_backend, but will really
#    2314     # foul things up if this isn't the owner)
#    2315     assert cls is cls._get_backend_owner(), "_finalize_backend() not invoked on owner"
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:2224, in BackendMixin._set_backend(cls, name, dryrun)
#    2222 if accepts_keyword(loader, "dryrun"):
#    2223     kwds['dryrun'] = dryrun
# -> 2224 ok = loader(**kwds)
#    2225 if ok is False:
#    2226     raise exc.MissingBackendError("%s: backend not available: %s" %
#    2227                                   (cls.name, name))
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/handlers/bcrypt.py:626, in _BcryptBackend._load_backend_mixin(mixin_cls, name, dryrun)
#     623     version = '<unknown>'
#     625 log.debug("detected 'bcrypt' backend, version %r", version)
# --> 626 return mixin_cls._finalize_backend_mixin(name, dryrun)
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/handlers/bcrypt.py:421, in _BcryptCommon._finalize_backend_mixin(mixin_cls, backend, dryrun)
#     419 else:
#     420     assert_lacks_8bit_bug(IDENT_2A)
# --> 421     if detect_wrap_bug(IDENT_2A):
#     422         if backend == "os_crypt":
#     423             # don't make this a warning for os crypt (e.g. openbsd);
#     424             # they'll have proper 2b implementation which will be used for new hashes.
#     425             # so even if we didn't have a workaround, this bug wouldn't be a concern.
#     426             log.debug("%r backend has $2a$ bsd wraparound bug, enabling workaround", backend)
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/handlers/bcrypt.py:380, in _BcryptCommon._finalize_backend_mixin.<locals>.detect_wrap_bug(ident)
#     378 secret = (b"0123456789"*26)[:255]
#     379 bug_hash = ident.encode("ascii") + b"04$R1lJ2gkNaoPGdafE.H.16.nVyh2niHsGJhayOHLMiXlI45o8/DU.6"
# --> 380 if verify(secret, bug_hash):
#     381     return True
#     383 # if it doesn't have wraparound bug, make sure it *does* handle things
#     384 # correctly -- or we're in some weird third case.
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/utils/handlers.py:792, in GenericHandler.verify(cls, secret, hash, **context)
#     790 if chk is None:
#     791     raise exc.MissingDigestError(cls)
# --> 792 return consteq(self._calc_checksum(secret), chk)
#
# File ~/Documents/Informatique/TrueLink/.venv/lib/python3.13/site-packages/passlib/handlers/bcrypt.py:655, in _BcryptBackend._calc_checksum(self, secret)
#     653 if isinstance(config, unicode):
#     654     config = config.encode("ascii")
# --> 655 hash = _bcrypt.hashpw(secret, config)
#     656 assert isinstance(hash, bytes)
#     657 if not hash.startswith(config) or len(hash) != len(config)+31:
#
# ValueError: password cannot be longer than 72 bytes, truncate manually if necessary (e.g. my_password[:72])
